# %%
# !pip install "pydantic-ai-slim[tavily]"
# Out:
# Requirement already satisfied: pydantic-ai-slim[tavily] in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (1.90.0)
# Requirement already satisfied: genai-prices>=0.0.48 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (0.0.57)
# Requirement already satisfied: griffelib>=2.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (2.0.2)
# Requirement already satisfied: httpx>=0.27 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (1.39.1)
# Requirement already satisfied: pydantic-graph==1.90.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (1.90.0)
# Requirement already satisfied: pydantic>=2.12 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (2.13.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (0.4.2)
# Requirement already satisfied: tavily-python>=0.5.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-ai-slim[tavily]) (0.7.24)
# Requirement already satisfied: logfire-api>=3.14.1 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic-graph==1.90.0->pydantic-ai-slim[tavily]) (4.32.1)
# Requirement already satisfied: anyio in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from httpx>=0.27->pydantic-ai-slim[tavily]) (4.13.0)
# Requirement already satisfied: certifi in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from httpx>=0.27->pydantic-ai-slim[tavily]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from httpx>=0.27->pydantic-ai-slim[tavily]) (1.0.9)
# Requirement already satisfied: idna in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from httpx>=0.27->pydantic-ai-slim[tavily]) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim[tavily]) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim[tavily]) (8.7.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim[tavily]) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim[tavily]) (3.23.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic>=2.12->pydantic-ai-slim[tavily]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from pydantic>=2.12->pydantic-ai-slim[tavily]) (2.46.3)
# Requirement already satisfied: requests in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from tavily-python>=0.5.0->pydantic-ai-slim[tavily]) (2.33.1)
# Requirement already satisfied: tiktoken>=0.5.1 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from tavily-python>=0.5.0->pydantic-ai-slim[tavily]) (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from tiktoken>=0.5.1->tavily-python>=0.5.0->pydantic-ai-slim[tavily]) (2026.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from requests->tavily-python>=0.5.0->pydantic-ai-slim[tavily]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/soham/VSCode/PydanticAI/venv/lib/python3.13/site-packages (from requests->tavily-python>=0.5.0->pydantic-ai-slim[tavily]) (2.6.3)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import nest_asyncio
nest_asyncio.apply()

from dotenv import load_dotenv
import os
import subprocess
load_dotenv(verbose=True)
# print(os.getenv("TAVILY_API_KEY"))
# Out:
# True

# %%
from pydantic_ai import Agent
from pydantic_ai.common_tools.tavily import tavily_search_tool

api_key = os.getenv('TAVILY_API_KEY')

# %%
agent = Agent(
    'groq:llama-3.3-70b-versatile',
    tools=[tavily_search_tool(api_key)],
    system_prompt=(
        "You are a highly capable AI assistant with access to the internet. "
        "Always use your search tool to find up-to-date information before answering."
    )
)

# %%
result = agent.run_sync('How to install Windows subsystem for linux?')
print(result.output)
# Out:
# To install the Windows Subsystem for Linux, you can follow these steps:
#
# 1. Open the Command Prompt or PowerShell as an administrator.
# 2. Type the command `wsl --install` and press Enter.
# 3. This will enable the features necessary to run WSL and install the Ubuntu distribution of Linux.
# 4. If you run `wsl --install` and see the WSL help text, please try running `wsl --list --online` to see a list of available distros and run `wsl --install -d`  to install a distro.
# 5. You can list your installed Linux distributions and check the version of WSL each is set to by entering the command: `wsl -l -v`.
# 6. To set the default version to WSL 1 or WSL 2 when a new Linux distribution is installed, use the command: `wsl --set-default-version <version>`.
#
# You can also install WSL by following the instructions on the Microsoft Learn website: https://learn.microsoft.com/en-us/windows/wsl/install.
