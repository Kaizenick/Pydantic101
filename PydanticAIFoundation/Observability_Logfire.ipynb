# %%
# !pip install logfire
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
"""
(venv) soham@Sohams-MacBook-Air-3 PydanticAI % logfire auth

Welcome to Logfire! 🔥
Before you can send data to Logfire, we need to authenticate you.

Logfire is available in multiple data regions. Please select one:
1. US (GCP region: us-east4)
2. EU (GCP region: europe-west4)
Selected region [1/2]: 1
Press Enter to open logfire-us.pydantic.dev in your browser...

Please open https://logfire-us.pydantic.dev/auth/device/KOr2j8G7r_D-YZ_Fv6LPYO8gfqagmgLnhxWga-gzuI8 in your browser to authenticate if it hasn't already.
Waiting for you to authenticate with Logfire...
Successfully authenticated!

Your Logfire credentials are stored in /Users/soham/.logfire/default.toml
(venv) soham@Sohams-MacBook-Air-3 PydanticAI % logfire projects use pydantic
Project configured successfully. You will be able to view it at: https://logfire-us.pydantic.dev/kaizenick77/pydantic
(venv) soham@Sohams-MacBook-Air-3 PydanticAI % 
(venv) soham@Sohams-MacBook-Air-3 PydanticAI % 
(venv) soham@Sohams-MacBook-Air-3 PydanticAI % logfire projects use pydantic       
Project configured successfully. You will be able to view it at: https://logfire-us.pydantic.dev/kaizenick77/pydantic
(venv) soham@Sohams-MacBook-Air-3 PydanticAI % 

"""

# %%
import logfire

logfire.configure()
logfire.info('Hello, {place}!', place='World')
# Out:
# No Logfire project credentials found.
# All data sent to Logfire must be associated with a project.
# Do you want to use one of your existing projects?  [y/n] (y):
