# %%
# !pip install -q langchain-community wikipedia
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import random
import nest_asyncio
nest_asyncio.apply()

import os 
from dotenv import load_dotenv
from pydantic_ai import Agent, RunContext
from dataclasses import dataclass

load_dotenv()
# Out:
# True

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

from langchain_community.tools import DuckDuckGoSearchRun

# %%
myagent = Agent("groq:openai/gpt-oss-120b",system_prompt="You are an agent who searches the internet in general and provide the user with the best information that answers the question they have asked!")

@myagent.tool_plain
def wikisearch(topic: str) -> str:
    """
    Always Use this function to get information for a topic
    """
    print("Searching wikipedia for : " + topic)
    wikipedia = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())
    return wikipedia.run(topic)

@myagent.tool_plain
def duckduckgosearch(topic: str) -> str:
    """
    Use this method to search the internet in general.
    """
    print("searching using duckduckgo!!")
    search = DuckDuckGoSearchRun()
    return search.invoke(topic)

# %%
myagent_response = myagent.run_sync("How to install windows subsystem for linux?")
# Out:
# searching using duckduckgo!!

# %%
myagent_response.output
# Out:
# "## Installing Windows Subsystem for Linux (WSL)\n\nWSL lets you run a full Linux environment (bash, utilities, and most command‑line apps) side‑by‑side with Windows. The installation is now a one‑command process on recent Windows builds, but I’ll also cover the manual steps for older versions or for people who prefer more control.\n\n---\n\n### 1️⃣ Prerequisites\n\n| Requirement | What to check / do |\n|-------------|--------------------|\n| **Windows version** | <ul><li>Windows\u202f10, version\u202f2004 or later (Build\u202f19041+)</li><li>Windows\u202f11 (any version)</li></ul> |\n| **Enable virtualization** | Most modern PCs have this on by default. You can verify in **Task Manager → Performance → CPU → Virtualization**. If it’s off, enable it in your BIOS. |\n| **Internet connection** | Needed to download the Linux distribution and the WSL kernel update package. |\n\n---\n\n### 2️⃣ Quick‑start (Windows\u202f10\u202f2004+/Windows\u202f11)\n\nOpen **PowerShell** **as Administrato
# ...
